# %% [markdown]
# <a href="https://colab.research.google.com/github/Karancse/Bank_Note_Authentication_using_MLDM/blob/main/Hierarchical_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt")
data
# Out:
#        3.6216    8.6661  -2.8073  -0.44699  0
# 0     4.54590   8.16740  -2.4586  -1.46210  0
# 1     3.86600  -2.63830   1.9242   0.10645  0
# 2     3.45660   9.52280  -4.0112  -3.59440  0
# 3     0.32924  -4.45520   4.5718  -0.98880  0
# 4     4.36840   9.67180  -3.9606  -3.16250  0
# ...       ...       ...      ...       ... ..
# 1366  0.40614   1.34920  -1.4501  -0.55949  1
# 1367 -1.38870  -4.87730   6.4774   0.34179  1
# 1368 -3.75030 -13.45860  17.5932  -2.77710  1
# 1369 -3.56370  -8.38270  12.3930  -1.28230  1
# 1370 -2.54190  -0.65804   2.6842   1.19520  1
#
# [1371 rows x 5 columns]

# %%
data.columns = ['VWT','SWT','CWT','E','C']
df = data.drop(['E'],axis=1) 
df.head()
# Out:
#        VWT     SWT     CWT  C
# 0  4.54590  8.1674 -2.4586  0
# 1  3.86600 -2.6383  1.9242  0
# 2  3.45660  9.5228 -4.0112  0
# 3  0.32924 -4.4552  4.5718  0
# 4  4.36840  9.6718 -3.9606  0

# %%
from sklearn import preprocessing

x = df.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
normalized_df = pd.DataFrame(x_scaled)
normalized_df.columns = ['VWT','SWT','CWT','C']

print(normalized_df)
# Out:
#            VWT       SWT       CWT    C
# 0     0.835659  0.820982  0.121804  0.0
# 1     0.786629  0.416648  0.310608  0.0
# 2     0.757105  0.871699  0.054921  0.0
# 3     0.531578  0.348662  0.424662  0.0
# 4     0.822859  0.877275  0.057100  0.0
# ...        ...       ...       ...  ...
# 1366  0.537124  0.565855  0.165249  1.0
# 1367  0.407690  0.332868  0.506753  1.0
# 1368  0.237385  0.011768  0.985603  1.0
# 1369  0.250842  0.201701  0.761587  1.0
# 1370  0.324528  0.490747  0.343348  1.0
#
# [1371 rows x 4 columns]

# %%
df = normalized_df

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

z_axis = df['SWT']
x_axis = df['VWT']
y_axis = df['CWT']
ax.scatter3D(x_axis, y_axis, z_axis, c=df['C'], cmap='rainbow')

# %%
plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(df, method='ward'))

# %%
cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')
cluster.fit_predict(df)
# Out:
# array([4, 1, 4, ..., 2, 2, 0])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
z_axis = df['SWT']
x_axis = df['VWT']
y_axis = df['CWT']
ax.scatter3D(x_axis, y_axis, z_axis, c=cluster.labels_)

# %%
sns.set(style="white", palette="muted", color_codes=True)


f, axes = plt.subplots(1, 3, figsize=(19, 7), sharex=True)
sns.despine(left=True)

sns.scatterplot(df['SWT'],df['VWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[0])
sns.scatterplot(df['SWT'],df['CWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[1])
sns.scatterplot(df['VWT'],df['CWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[2])

plt.setp(axes, yticks=[])
plt.tight_layout()

"""

f, axes = plt.subplots(1, 3, figsize=(18, 7), sharex=True)
sns.despine(left=True)

sns.scatterplot(df['SWT'],df['VWT'], hue=cluster.labels_, style=df['C'], size=1 , cmap='rainbow', markers = {0: "s", 1: "X"} , palette="deep", ax=axes[0])
sns.scatterplot(df['SWT'],df['CWT'], hue=cluster.labels_, style=df['C'], cmap='rainbow', markers = {0: "o", 1: "X"} , palette="deep", ax=axes[1])
sns.scatterplot(df['VWT'],df['CWT'], hue=cluster.labels_, style=df['C'], cmap='rainbow', ax=axes[2])

plt.setp(axes, yticks=[])
plt.tight_layout()

"""
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(df, method='complete'))

# %%
cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='complete')
cluster.fit_predict(df)
# Out:
# array([4, 1, 4, ..., 2, 2, 0])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

z_axis = df['SWT']
x_axis = df['VWT']
y_axis = df['CWT']
ax.scatter3D(x_axis, y_axis, z_axis, c=cluster.labels_)

# %%
sns.set(style="white", palette="muted", color_codes=True)


f, axes = plt.subplots(1, 3, figsize=(19, 7), sharex=True)
sns.despine(left=True)

sns.scatterplot(df['SWT'],df['VWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[0])
sns.scatterplot(df['SWT'],df['CWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[1])
sns.scatterplot(df['VWT'],df['CWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[2])

plt.setp(axes, yticks=[])
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10, 7))
plt.title("Customer Dendograms")
dend = shc.dendrogram(shc.linkage(df, method='average'))

# %%
cluster = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='average')
cluster.fit_predict(df)
# Out:
# array([1, 3, 1, ..., 0, 0, 2])

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

z_axis = df['SWT']
x_axis = df['VWT']
y_axis = df['CWT']
ax.scatter3D(x_axis, y_axis, z_axis, c=cluster.labels_)

# %%
sns.set(style="white", palette="muted", color_codes=True)


f, axes = plt.subplots(1, 3, figsize=(19, 7), sharex=True)
sns.despine(left=True)

sns.scatterplot(df['SWT'],df['VWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[0])
sns.scatterplot(df['SWT'],df['CWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[1])
sns.scatterplot(df['VWT'],df['CWT'], hue=cluster.labels_, cmap='rainbow', style=df['C'], markers = {0: "X", 1: "s"}, ax=axes[2])

plt.setp(axes, yticks=[])
plt.tight_layout()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
